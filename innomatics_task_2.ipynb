# %% [markdown]
# # Feb Internship Logic Building Task – 2
#
# Python Programming Practice Problems (1–10)

# %%
# Problem 1: Unique Words in a Sentence
sentence = input("Enter sentence: ")

words = sentence.split()
unique_words = set(words)
print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)
# Out:
# Enter sentence: hello python
# Unique words count: 2
# Unique words: {'python', 'hello'}

# %%
# Problem 2: Highest Salary from Employee Data
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

# Find the employee with the highest salary using the max function and a key
highest_employee = max(employees, key=employees.get)
print("Highest Salary:", highest_employee, "-", employees[highest_employee])
# Out:
# Highest Salary: Ravi - 75000

# %%
# Problem 3: Find Maximum and Minimum Values
numbers = [45, 22, 89, 10, 66]

max_val = numbers[0]
min_val = numbers[0]

for num in numbers:
    if num > max_val:
        max_val = num
    if num < min_val:
        min_val = num

print("List:", numbers)
print("Max:", max_val)
print("Min:", min_val)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %%
# Problem 4: Count Products Above a Price Threshold
prices = [450, 1200, 899, 1500, 300]

count = 0
for price in prices:
    if price > 1000:
        count += 1

print("Products above 1000:", count)
# Out:
# Products above 1000: 2

# %%
# Problem 5: Calculate Attendance Percentage
attendance = ["P", "P", "A", "P", "P"]

present_days = attendance.count("P") # Count occurrences of 'P' (present)
# Calculate percentage: (present days / total days) * 100
percentage = (present_days / len(attendance)) * 100

print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 80.0

# %%
# Problem 6: Remove Duplicate Phone Numbers
phone_numbers = [9876543210, 9123456789, 9876543210]

unique_numbers = set(phone_numbers) # Convert list to a set to automatically remove duplicates
print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %%
# Problem 7: Count Character Frequency
text = "python"

char_freq = {}
for ch in text:
    # Increment count for each character, or initialize to 1 if first occurrence
    char_freq[ch] = char_freq.get(ch, 0) + 1

print(char_freq)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %%
# Problem 8: Convert List to Tuple
numbers_list = [10, 20, 30]

numbers_tuple = tuple(numbers_list) # Convert the list to a tuple
print("Tuple:", numbers_tuple)
# Out:
# Tuple: (10, 20, 30)

# %%
# Problem 9: Check if a Key Exists in a Dictionary
employees = {"Ravi": 75000, "Anita": 68000}
key_to_check = "Ravi"

# Use 'in' operator to check for key existence
if key_to_check in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %%
# Problem 10: Calculate Average Marks
marks = [70, 75, 65, 80]

# Calculate the sum and divide by the number of elements to get the average
average = sum(marks) / len(marks)
print("Average Marks:", average)
# Out:
# Average Marks: 72.5
